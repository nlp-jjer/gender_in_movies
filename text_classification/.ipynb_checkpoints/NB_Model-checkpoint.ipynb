# %% [markdown]
# ### Purpose
# Playing around with NB Multinormial language modeling. Eventually need to turn this into a .py file.

# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn import metrics 
from IPython.core.interactiveshell import InteractiveShell
import classification_pipeline as pipeline
from scipy import sparse


InteractiveShell.ast_node_interactivity = "all"

# %%
df = pickle.load(open("../data/movies_lines_train.p", 'rb'))

# %%
df.shape
df.head()
# Out:
# (202394, 9)
#   movie_id gender_to gender_from char_id_from char_id_to line_id  \
# 0      m18         m           m         u284       u288  L34746
# 1      m18         m           m         u284       u288  L34747
# 2      m18         m           m         u284       u288  L34748
# 3      m18         m           m         u284       u288  L34749
# 4      m18         m           m         u284       u288  L34750
#
#                                         words movie_year  genre
# 0                                   hello tom       1932  drama
# 1                                you you want       1932  drama
# 2  you suppose anybody want money money money       1932  drama
# 3       listen i tell you i interested deal i       1932  drama
# 4                                 i want know       1932  drama

# %%
df.genre.unique()
# Out:
# array(['drama', 'action', 'adventure', 'horror', 'comedy', 'mystery',
#        'animation', 'thriller', 'crime', 'short', 'fantasy', 'biography',
#        'documentary', 'sci-fi', 'family'], dtype=object)

# %%
df = pipeline.add_columns(df)

# %%
df.head()
# Out:
#   movie_id  gender_to  gender_from char_id_from char_id_to line_id  \
# 0      m18          0            0         u284       u288  L34746
# 1      m18          0            0         u284       u288  L34747
# 2      m18          0            0         u284       u288  L34748
# 3      m18          0            0         u284       u288  L34749
# 4      m18          0            0         u284       u288  L34750
#
#                                         words movie_year  genre  gender_pair  \
# 0                                   hello tom       1932  drama            0
# 1                                you you want       1932  drama            0
# 2  you suppose anybody want money money money       1932  drama            0
# 3       listen i tell you i interested deal i       1932  drama            0
# 4                                 i want know       1932  drama            0
#
#    agency_pos_prop  power_pos_prop  agency_neg_prop  power_neg_prop  \
# 0         0.000000             0.0              0.0             0.0
# 1         0.000000             0.0              1.0             1.0
# 2         0.000000             0.0              0.5             0.5
# 3         0.333333             0.0              0.0             0.0
# 4         0.000000             0.0              1.0             1.0
#
#          MT1        MT2        MT3       WT1       WT2       WT3
# 0  27.474762  31.052752  30.398746  3.368221  3.309822  2.475675
# 1  27.471319  32.046505  28.411058  4.286404  3.240317  2.391138
# 2  30.733057  33.307358  28.655600  4.590682  3.429439  2.629144
# 3  27.688360  33.289986  29.672899  3.286407  4.240316  2.391139
# 4  27.471331  33.046471  28.411070  4.286404  3.240317  2.391138

# %%
FEATURE_COLS = ['words', 'agency_pos_prop','power_pos_prop', 'agency_neg_prop','power_neg_prop',
                'MT1','MT2', 'MT3','WT1','WT2','WT3']

# %%
X_train, X_test, y_train, y_test = train_test_split(df[FEATURE_COLS], df.gender_from.astype('int'), test_size=0.33, random_state=42)

# %%
y_train.value_counts()
y_test.value_counts()
# Out:
# 0    73123
# 1    32331
# Name: gender_from, dtype: int64
# 0    36059
# 1    15882
# Name: gender_from, dtype: int64

# %%
X_train.shape
X_test.shape
# Out:
# (105454, 11)
# (51941, 11)

# %%
def transform_train(X_train, ngram_range = (1,1)):
    '''
    Process text features of training dataframe
    '''
    count_vect = CountVectorizer(ngram_range = ngram_range) # using bag of words
    tfidf_transformer = TfidfTransformer()
    
    # vectorize the text column
    X_train_counts = count_vect.fit_transform(X_train.words)    
    X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
    
    # combine sparse matrix of text features with other features
    X_train_others = sparse.csr_matrix(X_train.loc[:, X_train.columns != 'words'])
    X_train_tfidf_combined = sparse.hstack((X_train_tfidf, X_train_others)).tocsr()
    
    return X_train_tfidf_combined, count_vect, tfidf_transformer


def transform_test(X_test, count_vect, tfidf_transformer):
    '''
    Process test features of testing dataframe, using count_vect and 
    tfidf_transformer created on training data
    '''
    X_test_counts = count_vect.transform(X_test.words)
    X_test_tfidf = tfidf_transformer.transform(X_test_counts)
    
    # combine sparse matrix of text features with other features
    X_test_others = sparse.csr_matrix(X_test.loc[:, X_test.columns != 'words'])
    X_test_tfidf_combined = sparse.hstack((X_test_tfidf, X_test_others)).tocsr()
    
    return X_test_tfidf_combined

# %%
X_train_tfidf_combined, count_vect, tfidf_transformer = transform_train(X_train, ngram_range = (1,1))
X_test_tfidf_combined = transform_test(X_test, count_vect, tfidf_transformer)

# %%
# train - this is the final classifier we ended up using
clf = MultinomialNB(alpha=0.5).fit(X_train_tfidf_combined, y_train)

# %%
# test
predicted = clf.predict(X_test_tfidf_combined)
proba = clf.predict_proba(X_test_tfidf_combined)

# %%
np.bincount(predicted)
predicted
proba
# Out:
# array([41573, 10368], dtype=int64)
# array([0, 0, 1, ..., 1, 0, 1])
# array([[0.76941752, 0.23058248],
#        [0.91346706, 0.08653294],
#        [0.36630479, 0.63369521],
#        ...,
#        [0.14512868, 0.85487132],
#        [0.93265015, 0.06734985],
#        [0.11940057, 0.88059943]])

# %% [markdown]
# ### Classifier results - not spectacular but better than before
#
# Using unigrams + bigrams does worse than simple bag of words approach

# %%
print('accuracy: ', metrics.accuracy_score(y_test, predicted))
print('precision: ', metrics.precision_score(y_test, predicted))
print('recall: ', metrics.recall_score(y_test, predicted))
metrics.confusion_matrix(y_test, predicted)
# Out:
# accuracy:  0.6454053637781328
# precision:  0.3777006172839506
# recall:  0.2465684422616799
# array([[29607,  6452],
#        [11966,  3916]], dtype=int64)

# %% [markdown]
# ### Explore results of classifier on holdout set

# %%
# read in lines df
def simple_process(filepath, headers):
    lines = []

    to_longform  = ['text', 'line_id', 'genre']
    idx_col, tgt_col = (headers[:-1], headers[-1])

    with open(filepath, 'r', encoding = 'iso-8859-1') as f:
        for line in f:
            cols = line.split(' +++$+++ ')
            lines.append(cols)

    df = pd.DataFrame(lines, columns = headers)
    return df

# %%
file_lines = '../cornell_movie_dialogs_corpus/movie_lines.txt'
header_lines = ['line_id', 'char_id', 'movie_id', 'char_name','text']
lines = simple_process(file_lines, header_lines)
lines.head()
# Out:
#   line_id char_id movie_id char_name            text
# 0   L1045      u0       m0    BIANCA  They do not!\n
# 1   L1044      u2       m0   CAMERON   They do to!\n
# 2    L985      u0       m0    BIANCA    I hope so.\n
# 3    L984      u2       m0   CAMERON     She okay?\n
# 4    L925      u0       m0    BIANCA     Let's go.\n

# %%
file_titles = '../cornell_movie_dialogs_corpus/movie_titles_metadata.txt'
header_titles = ['movie_id', 'movie_title', 'movie_year', 'imdb_rating', 'imdb_vote', 'genre']
titles = simple_process(file_titles, header_titles)
titles.head()
# Out:
#   movie_id                 movie_title movie_year imdb_rating imdb_vote  \
# 0       m0  10 things i hate about you       1999        6.90     62847
# 1       m1  1492: conquest of paradise       1992        6.20     10421
# 2       m2                  15 minutes       2001        6.10     25854
# 3       m3       2001: a space odyssey       1968        8.40    163227
# 4       m4                     48 hrs.       1982        6.90     22289
#
#                                                genre
# 0                            ['comedy', 'romance']\n
# 1   ['adventure', 'biography', 'drama', 'history']\n
# 2         ['action', 'crime', 'drama', 'thriller']\n
# 3               ['adventure', 'mystery', 'sci-fi']\n
# 4  ['action', 'comedy', 'crime', 'drama', 'thrill...

# %%
movies_holdout = pickle.load(open("../data/movies_lines_holdout.p", 'rb'))

# %%
# same as the classifier trained above
classifier_object = pickle.load(open("../text_classification/mnb_final.p", 'rb'))

# %%
preds, pred_probs, X_holdout = pipeline.classify_unseen(movies_holdout, classifier_object, FEATURE_COLS)

# %%
print('accuracy: ', metrics.accuracy_score(X_holdout.gender_from, preds))
print('precision: ', metrics.precision_score(X_holdout.gender_from, preds))
print('recall: ', metrics.recall_score(X_holdout.gender_from, preds))
metrics.confusion_matrix(X_holdout.gender_from, preds)
# Out:
# accuracy:  0.6177432040505334
# precision:  0.364358813103882
# recall:  0.24176783004552352
# array([[43894, 11118],
#        [19987,  6373]], dtype=int64)

# %%
X_holdout[FEATURE_COLS].head(10)
# Out:
#                                                                       words  \
# 0  thanks miss
# 1  you kind i amanda
# 2  right well thanks drink stuff amanda reason me stick around part anymore
# 3  glum hawk night still young fill plenty compensatory possibility
# 4  huh
# 5  i position spend money you you get position spend time me
# 6  hell
# 7  gin
# 8  whoa hard liquor tad manly me i brewski man myself
# 9  well ease hawk want give you whiskey dick would we
#
#    agency_pos_prop  power_pos_prop  agency_neg_prop  power_neg_prop       MT1  \
# 0  0.0              0.0             1.000000         1.000000        6.131145
# 1  0.0              0.0             0.000000         0.000000        6.211220
# 2  1.0              0.5             0.000000         0.000000        6.347796
# 3  0.0              0.0             0.000000         0.000000        7.570643
# 4  0.0              0.0             0.000000         0.000000        6.131144
# 5  0.5              0.5             0.000000         0.000000        6.238618
# 6  0.0              0.0             0.000000         0.000000        6.131144
# 7  0.0              0.0             0.000000         0.000000        6.212213
# 8  0.0              0.0             0.000000         0.000000        6.633988
# 9  0.0              0.0             0.333333         0.333333        6.604615
#
#         MT2       MT3       WT1       WT2       WT3
# 0  6.841707  6.666505  4.747797  4.686748  4.755125
# 1  6.929817  6.751709  4.744825  4.684112  4.752109
# 2  7.081794  6.892825  7.110352  4.904115  4.974433
# 3  8.195575  6.987399  5.852607  5.792455  6.897112
# 4  6.841705  7.666502  4.662018  4.601227  4.668652
# 5  6.959878  6.781432  4.900751  4.786988  5.950361
# 6  6.841705  6.666503  4.662022  4.601231  4.668655
# 7  6.930942  6.752777  4.747345  4.686301  4.754926
# 8  7.352735  8.250304  4.888698  4.744660  4.808101
# 9  7.363715  7.169038  4.889926  4.831149  4.898713

# %% [markdown]
# The most likely male lines from holdout set

# %%
most_male = X_holdout.sort_values(by='male_prob', ascending=False).head(5)
most_male = most_male[['line_id', 'male_prob']].merge(lines, on='line_id').merge(titles, on='movie_id')

# %%
pd.set_option('display.max_colwidth', -1)
most_male[['movie_title', 'text', 'movie_year', 'male_prob', 'genre']]
# Out:
#            movie_title  \
# 0  glengarry glen ross
# 1  glengarry glen ross
# 2  the majestic
# 3  good will hunting
# 4  grand hotel
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text  \
# 0  That's what I'm saying.  The old ways.  The old ways...convert the motherfucker...sell him...sell him... make him sign the check.  The...Bruce, Harriet...the kitchen, blah: they got their money in government bonds...I say fuck it, we're going to go the whole route. I plat it out eight units.  Eighty- two grand.  I tell them. "This is now.  This is that thing that you've been dreaming of, you're going to find that suitcase on the train, the guy comes in the door, the bag that's full of money.  This is it, Harriett..."\n
# 1  Get the chalk.  Get the chalk...get the chalk!  I closed 'em!  I closed the cocksucker.  Get the chalk and put me on the board.  I'm going to Hawaii!  Put me on the Cadillac board, Williamson!  Pick up the fuckin' chalk.  Eight units. Mountain View...\n
# 2  Leo, I was trying to impress a skirt.  You know me, I'm non- political.  Republican, Democrat, Communist, there's not a dime's worth of difference between 'em anyway.\n
# 3  There goes that fuckin' Barney right now, with his fuckin' "skiin' trip." We should'a kicked that dude's ass.\n
# 4  I'm Baron von Gaigern.\n
#
#   movie_year  male_prob                   genre
# 0  1992       0.994480   ['drama']\n
# 1  1992       0.994430   ['drama']\n
# 2  2001       0.994445   ['drama', 'romance']\n
# 3  1997       0.994079   ['drama']\n
# 4  1932       0.993760   ['drama', 'romance']\n

# %% [markdown]
# The most likely female lines form holdout set

# %%
most_female = X_holdout.sort_values(by='female_prob', ascending=False).head(20)
most_female = most_female[['line_id', 'female_prob']].merge(lines, on='line_id').merge(titles, on='movie_id')

# %%
pd.set_option('display.max_colwidth', -1)
most_female[['movie_title', 'text', 'movie_year', 'female_prob', 'genre']]
# Out:
#                                     movie_title  \
# 0   leviathan
# 1   ghost ship
# 2   ghost ship
# 3   ghost ship
# 4   ghost ship
# 5   frances
# 6   a nightmare on elm street 3: dream warriors
# 7   back to the future
# 8   the time machine
# 9   halloween
# 10  halloween
# 11  house of 1000 corpses
# 12  house of 1000 corpses
# 13  jennifer eight
# 14  le grand bleu
# 15  1492: conquest of paradise
# 16  jaws 2
# 17  friday the 13th part iii
# 18  i walked with a zombie
# 19  i walked with a zombie
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text  \
# 0   Your suit, Becky!\n
# 1   Maureen?\n
# 2   Maureen.\n
# 3   Maureen.\n
# 4   Let's not be too hasty.\n
# 5   Claire?\n
# 6   You like gymnastics?\n
# 7   It's polyester.\n
# 8   She's gotten into your equations.\n
# 9   Annie!\n
# 10  Annie, was that you?\n
# 11  Shhhhhh.\n
# 12  Shhhhhh.\n
# 13  <u>Hit those wipers, Ross</u>.\n
# 14  You look adorable.\n
# 15  How are you feeling, Fernando?\n
# 16  Santos' place.\n
# 17  When you dropped me off at the house, it was very late.  My parents were waiting up for me. As soon as I got in the door, they starting yelling and cursing at me.  I was so upset... I told them I slept with you.  My mothers slapped me.  That was the first time she'd ever hit me.  I couldn't believe it.  I ran out of the house and into the woods as fast and as far as I could run. I was crying.  They had destroyed the most beautiful night of my life and I wanted to punish them for that.  I decided to hide out all night.  They'd be so worried that they'd be sorry for what they did to me.  The woods were cold and damp from the rain.  I found a dry spot under a rotted oak tree and I guess I fell asleep.  All I can remember next is being startled out of sleep by the sound of footsteps.  I thought it was my father so I hid behind the tree. But the footsteps just stopped. The woods were dark.  I couldn't see anything.  I heard a cracking noise behind me.  I turned around and... and... oh, God... there was this hideous looking man.  So grotesque he was almost inhuman.  He had a knife and he started to slash away at me, again and again.  I was so hysterical and I don't know how I was able to get away.  I ran and ran, but he kept coming.  He was big but so fast.  He caught me and pulled me down to the ground and he... he... ripped my blouse off. I was screaming, but who could hear me?  Then... oh, God... he dragged me by the hair along the ground.  I was kicking and yelling.  He dragged me deeper and deeper into the woods.  Oh, please... please...\n
# 18  What I saw the other night, I didn't dare believe, Betsy --\n
# 19  Betsy, can I talk to you a minute?\n
#
#    movie_year  female_prob  \
# 0   1989       0.987255
# 1   2002       0.985189
# 2   2002       0.985189
# 3   2002       0.985189
# 4   2002       0.975697
# 5   1982       0.985081
# 6   1987       0.982592
# 7   1985       0.982228
# 8   2002       0.981690
# 9   1978       0.981643
# 10  1978       0.980624
# 11  2003       0.980443
# 12  2003       0.980443
# 13  1992       0.980421
# 14  1988       0.979427
# 15  1992       0.978249
# 16  1978       0.977303
# 17  1982       0.976890
# 18  1943       0.975847
# 19  1943       0.975773
#
#                                                          genre
# 0   ['adventure', 'horror', 'mystery', 'sci-fi', 'thriller']\n
# 1   ['horror', 'mystery', 'thriller']\n
# 2   ['horror', 'mystery', 'thriller']\n
# 3   ['horror', 'mystery', 'thriller']\n
# 4   ['horror', 'mystery', 'thriller']\n
# 5   ['biography', 'drama']\n
# 6   ['fantasy', 'horror', 'thriller']\n
# 7   ['adventure', 'family', 'sci-fi']\n
# 8   ['sci-fi', 'adventure', 'action']\n
# 9   ['horror', 'thriller']\n
# 10  ['horror', 'thriller']\n
# 11  ['horror']\n
# 12  ['horror']\n
# 13  ['thriller', 'mystery']\n
# 14  ['adventure', 'drama', 'romance']\n
# 15  ['adventure', 'biography', 'drama', 'history']\n
# 16  ['thriller']\n
# 17  ['horror']\n
# 18  ['horror']\n
# 19  ['horror']\n

# %% [markdown]
# Look at average probs across movies

# %%
groupby_movie = X_holdout[['movie_id', 'gender_from', 'male_prob', 'female_prob']].groupby(by = 'movie_id')

# %%
mapper = {'gender_from':'avg_prop_female_lines', 'male_prob':'avg_male_prob', 'female_prob':'avg_female_prob'}

# %%
most_male_overall = groupby_movie.mean().sort_values(by='male_prob', ascending=False).head(10).reset_index()
most_male_overall = most_male_overall[['movie_id', 'gender_from', 'male_prob']].merge(titles, on='movie_id')
most_male_overall.rename(columns=mapper, inplace=True)
most_male_overall[['avg_prop_female_lines', 'avg_male_prob', 'movie_title', 'movie_year', 'genre']]
# Out:
#    avg_prop_female_lines  avg_male_prob                      movie_title  \
# 0  0.034921               0.937486       true believer
# 1  0.068337               0.936244       apocalypse now
# 2  0.000000               0.933414       glengarry glen ross
# 3  0.152695               0.933175       do the right thing
# 4  0.322251               0.932354       the majestic
# 5  0.421941               0.931982       one flew over the cuckoo's nest
# 6  0.101617               0.931890       nothing but a man
# 7  0.436293               0.931512       affliction
# 8  0.024691               0.931115       the verdict
# 9  0.346705               0.930441       the day the earth stood still
#
#   movie_year                               genre
# 0  1989       ['drama', 'crime']\n
# 1  1979       ['drama', 'war']\n
# 2  1992       ['drama']\n
# 3  1989       ['drama']\n
# 4  2001       ['drama', 'romance']\n
# 5  1975       ['drama']\n
# 6  1964       ['drama', 'romance']\n
# 7  1997       ['drama', 'mystery', 'thriller']\n
# 8  1982       ['drama']\n
# 9  2008       ['drama', 'sci-fi', 'thriller']\n

# %%
most_female_overall = groupby_movie.mean().sort_values(by='female_prob', ascending=False).head(10).reset_index()
most_female_overall = most_female_overall[['movie_id', 'gender_from', 'female_prob']].merge(titles, on='movie_id')
most_female_overall.rename(columns=mapper, inplace=True)
most_female_overall[['avg_prop_female_lines', 'avg_female_prob', 'movie_title', 'movie_year', 'genre']]
# Out:
#    avg_prop_female_lines  avg_female_prob  \
# 0  1.000000               0.860538
# 1  0.183036               0.845237
# 2  0.333333               0.842549
# 3  0.800752               0.841393
# 4  0.569519               0.840736
# 5  0.667470               0.839264
# 6  0.450746               0.839212
# 7  0.202247               0.838664
# 8  0.241379               0.838109
# 9  0.804800               0.837933
#
#                              movie_title movie_year  \
# 0  i walked with a zombie                 1943
# 1  le grand bleu                          1988
# 2  friday the 13th part iii               1982
# 3  i still know what you did last summer  1998
# 4  cherry falls                           2000
# 5  the wizard of oz                       1939
# 6  ghostbusters                           1986
# 7  back to the future                     1985
# 8  the beach                              2000/I
# 9  the curse                              1987
#
#                                                       genre
# 0  ['horror']\n
# 1  ['adventure', 'drama', 'romance']\n
# 2  ['horror']\n
# 3  ['horror', 'mystery', 'thriller']\n
# 4  ['horror', 'mystery', 'thriller']\n
# 5  ['adventure', 'family', 'fantasy', 'musical']\n
# 6  ['animation', 'comedy', 'fantasy', 'sci-fi', 'horror']\n
# 7  ['adventure', 'family', 'sci-fi']\n
# 8  ['adventure', 'drama', 'romance', 'thriller']\n
# 9  ['sci-fi', 'horror']\n

# %% [markdown]
# ### Explore gender proportions

# %%
movies[movies.movie_id == 'm0']

# %%
X_holdout.shape
# Out:
# (81372, 22)

# %%
groupby_movie = X_holdout[['movie_id', 'gender_from', 'male_prob', 'female_prob']].groupby(['movie_id', 'gender_from'])

# %%
line_counts = groupby_movie.size().unstack(fill_value=0).reset_index()
line_counts.rename(columns = {0:'male_line_ct', 1:'female_line_ct'}, inplace = True)
line_counts['pct_female'] = line_counts.female_line_ct / (line_counts.male_line_ct + line_counts.female_line_ct)

# %%
most_female_lines = line_counts.sort_values(by='pct_female', ascending=False).head(10).merge(titles, on='movie_id')
most_female_lines
# Out:
#   movie_id  male_line_ct  female_line_ct  pct_female  \
# 0  m594     0             614             1.000000
# 1  m279     0             511             1.000000
# 2  m396     0             218             1.000000
# 3  m234     16            772             0.979695
# 4  m376     35            652             0.949054
# 5  m8       12            158             0.929412
# 6  m475     27            338             0.926027
# 7  m604     15            132             0.897959
# 8  m312     79            637             0.889665
# 9  m188     45            330             0.880000
#
#                                   movie_title movie_year imdb_rating  \
# 0  vertigo                                     1958       8.60
# 1  the bridges of madison county               1995       7.20
# 2  i walked with a zombie                      1943       7.30
# 3  agnes of god                                1985       6.50
# 4  the horse whisperer                         1998       6.40
# 5  a nightmare on elm street: the dream child  1989       4.70
# 6  playback                                    1996       3.60
# 7  white angel                                 1994       4.40
# 8  cruel intentions                            1999       6.70
# 9  someone to watch over me                    1987       6.10
#
#   imdb_vote                                                  genre
# 0  93524     ['crime', 'mystery', 'romance', 'thriller']\n
# 1  22252     ['drama', 'romance']\n
# 2  3420      ['horror']\n
# 3  3490      ['drama', 'mystery', 'thriller']\n
# 4  15953     ['drama', 'romance', 'western']\n
# 5  11092     ['fantasy', 'horror', 'thriller']\n
# 6  164       ['thriller']\n
# 7  99        ['drama', 'thriller']\n
# 8  67532     ['drama', 'romance', 'thriller']\n
# 9  3909      ['action', 'crime', 'drama', 'romance', 'thriller']\n

# %%
most_male_lines = line_counts.sort_values(by='pct_female', ascending=True).head(60).merge(titles, on='movie_id')
most_male_lines
# Out:
#    movie_id  male_line_ct  female_line_ct  pct_female  \
# 0   m96      113           0               0.000000
# 1   m45      474           0               0.000000
# 2   m442     391           0               0.000000
# 3   m440     219           0               0.000000
# 4   m434     400           0               0.000000
# 5   m197     242           0               0.000000
# 6   m421     180           0               0.000000
# 7   m368     884           0               0.000000
# 8   m358     446           0               0.000000
# 9   m357     90            0               0.000000
# 10  m339     88            0               0.000000
# 11  m214     452           0               0.000000
# 12  m226     86            0               0.000000
# 13  m319     203           0               0.000000
# 14  m316     491           0               0.000000
# 15  m31      343           0               0.000000
# 16  m309     268           0               0.000000
# 17  m300     454           0               0.000000
# 18  m284     360           0               0.000000
# 19  m280     224           0               0.000000
# 20  m456     29            0               0.000000
# 21  m490     114           0               0.000000
# 22  m187     297           0               0.000000
# 23  m568     303           0               0.000000
# 24  m77      957           0               0.000000
# 25  m592     215           0               0.000000
# 26  m587     240           0               0.000000
# 27  m107     9             0               0.000000
# 28  m583     224           0               0.000000
# 29  m570     713           0               0.000000
# 30  m495     575           0               0.000000
# 31  m535     50            0               0.000000
# 32  m52      301           0               0.000000
# 33  m514     347           0               0.000000
# 34  m262     239           0               0.000000
# 35  m145     345           0               0.000000
# 36  m497     244           0               0.000000
# 37  m595     767           16              0.020434
# 38  m367     393           9               0.022388
# 39  m230     692           16              0.022599
# 40  m225     553           14              0.024691
# 41  m512     547           15              0.026690
# 42  m166     359           11              0.029730
# 43  m223     304           11              0.034921
# 44  m50      379           14              0.035623
# 45  m578     286           13              0.043478
# 46  m403     591           31              0.049839
# 47  m108     335           18              0.050992
# 48  m251     489           29              0.055985
# 49  m337     334           22              0.061798
# 50  m179     239           16              0.062745
# 51  m163     559           38              0.063652
# 52  m471     407           28              0.064368
# 53  m496     382           28              0.068293
# 54  m247     409           30              0.068337
# 55  m267     475           36              0.070450
# 56  m143     192           16              0.076923
# 57  m182     206           18              0.080357
# 58  m46      417           40              0.087527
# 59  m243     820           79              0.087875
#
#                                movie_title movie_year imdb_rating imdb_vote  \
# 0   invaders from mars                      1953       6.40        2115
# 1   confidence                              2003       6.80        17235
# 2   mission: impossible ii                  2000       5.70        86452
# 3   mimic                                   1997       5.70        14916
# 4   halloween iii: season of the witch      1982       3.80        13037
# 5   star trek vi: the undiscovered country  1991       7.20        23751
# 6   leviathan                               1989       5.30        4751
# 7   glengarry glen ross                     1992       7.90        32882
# 8   frequency                               2000       7.30        36396
# 9   the french connection                   1971       7.90        34062
# 10  escape from l.a.                        1996       5.30        23551
# 11  the time machine                        2002       5.70        32900
# 12  the war of the worlds                   1953       7.10        12239
# 13  deep rising                             1998       5.70        12638
# 14  dave                                    1993       6.80        20807
# 15  birthday girl                           2001       6.00        13497
# 16  crime spree                             2003       6.40        3129
# 17  cliffhanger                             1993       6.20        34880
# 18  bringing out the dead                   1999       6.80        31285
# 19  bones                                   2001       4.00        3525
# 20  the negotiator                          1998       7.20        46983
# 21  the rocky horror picture show           1975       7.10        42713
# 22  solaris                                 2002       6.20        33541
# 23  the sting                               1973       8.40        67231
# 24  the graduate                            1967       8.20        79677
# 25  the usual suspects                      1995       8.70        272137
# 26  twelve monkeys                          1995       8.10        173320
# 27  jason x                                 2001       4.40        18199
# 28  star trek v: the final frontier         1989       5.00        20749
# 29  three kings                             1999       7.30        69757
# 30  route 9                                 1998       6.00        557
# 31  stranglehold                            2007       8.60        907
# 32  duck soup                               1933       8.10        27112
# 33  the shining                             1980       8.50        182077
# 34  batman                                  1989       7.60        112731
# 35  next friday                             2000       5.40        10267
# 36  rush hour                               1998       6.80        56376
# 37  very bad things                         1998       6.00        22977
# 38  get carter                              2000       4.80        14319
# 39  wonder boys                             2000       7.50        31853
# 40  the verdict                             1982       7.70        10991
# 41  shallow grave                           1994       7.40        21611
# 42  raging bull                             1980       8.40        91851
# 43  true believer                           1989       6.70        1801
# 44  donnie darko                            2001       8.30        215194
# 45  to sleep with anger                     1990       6.80        490
# 46  jaws 2                                  1978       5.60        18995
# 47  jaws                                    1975       8.30        140982
# 48  asylum                                  2005       6.10        2395
# 49  star wars: the empire strikes back      1982       8.00        42
# 50  signs                                   2002       6.90        113119
# 51  punch-drunk love                        2002       7.40        50312
# 52  philadelphia                            1993       7.60        54221
# 53  rush hour 2                             2001       6.50        52716
# 54  apocalypse now                          1979       8.60        176465
# 55  being john malkovich                    1999       7.90        115008
# 56  mystery men                             1999       5.90        31817
# 57  the sixth sense                         1999       8.20        244162
# 58  croupier                                1998       7.20        9060
# 59  annie hall                              1977       8.30        66781
#
#                                                                genre
# 0   ['horror', 'sci-fi']\n
# 1   ['crime', 'thriller']\n
# 2   ['action', 'adventure', 'thriller']\n
# 3   ['drama', 'horror', 'sci-fi']\n
# 4   ['horror', 'mystery', 'sci-fi']\n
# 5   ['action', 'mystery', 'sci-fi', 'thriller']\n
# 6   ['adventure', 'horror', 'mystery', 'sci-fi', 'thriller']\n
# 7   ['drama']\n
# 8   ['crime', 'drama', 'sci-fi', 'thriller']\n
# 9   ['action', 'crime', 'thriller']\n
# 10  ['action', 'adventure', 'sci-fi', 'thriller']\n
# 11  ['sci-fi', 'adventure', 'action']\n
# 12  ['action', 'horror', 'sci-fi', 'thriller']\n
# 13  ['action', 'horror', 'sci-fi', 'thriller']\n
# 14  ['comedy', 'romance']\n
# 15  ['comedy', 'crime', 'romance', 'thriller']\n
# 16  ['action', 'comedy', 'crime']\n
# 17  ['action', 'adventure', 'thriller']\n
# 18  ['drama', 'thriller']\n
# 19  ['crime', 'horror']\n
# 20  ['action', 'crime', 'drama', 'mystery', 'thriller']\n
# 21  ['comedy', 'musical']\n
# 22  ['drama', 'mystery', 'romance', 'sci-fi']\n
# 23  ['comedy', 'crime', 'drama']\n
# 24  ['comedy', 'drama', 'romance']\n
# 25  ['crime', 'mystery', 'thriller']\n
# 26  ['mystery', 'sci-fi', 'thriller']\n
# 27  ['horror', 'sci-fi']\n
# 28  ['action', 'adventure', 'sci-fi', 'thriller']\n
# 29  ['action', 'adventure', 'comedy', 'drama', 'war']\n
# 30  ['crime', 'drama']\n
# 31  ['action', 'adventure', 'crime']\n
# 32  ['comedy', 'musical']\n
# 33  ['horror', 'mystery', 'thriller']\n
# 34  ['crime', 'drama', 'thriller', 'action', 'adventure', 'crime']\n
# 35  ['comedy']\n
# 36  ['action', 'comedy', 'thriller', 'crime']\n
# 37  ['comedy', 'crime', 'thriller']\n
# 38  ['action', 'crime', 'drama', 'thriller']\n
# 39  ['drama', 'comedy']\n
# 40  ['drama']\n
# 41  ['comedy', 'crime', 'drama', 'thriller']\n
# 42  ['biography', 'drama', 'sport']\n
# 43  ['drama', 'crime']\n
# 44  ['drama', 'mystery', 'sci-fi']\n
# 45  ['drama']\n
# 46  ['thriller']\n
# 47  ['thriller']\n
# 48  ['drama', 'romance', 'thriller']\n
# 49  ['animation', 'adventure', 'action', 'fantasy']\n
# 50  ['drama', 'mystery', 'sci-fi', 'thriller']\n
# 51  ['comedy', 'drama', 'romance']\n
# 52  ['drama']\n
# 53  ['action', 'comedy', 'crime', 'thriller']\n
# 54  ['drama', 'war']\n
# 55  ['comedy', 'drama', 'fantasy', 'romance']\n
# 56  ['action', 'comedy', 'fantasy']\n
# 57  ['drama', 'mystery', 'thriller']\n
# 58  ['crime', 'drama']\n
# 59  ['comedy', 'drama', 'romance']\n

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = line_counts.pct_female
plt.figure(figsize=(10,8))
plt.hist(x, bins=30, color='gray')
plt.xlabel('% of movie lines that are female', fontsize = 15);
plt.title('Distribution of female line proportions', fontsize = 20);
