# %%
import pickle
import pandas as pd
import numpy as np
import nltk
from nltk.util import ngrams
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn import metrics 
from sklearn.decomposition import NMF, LatentDirichletAllocation
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
# print (pd.__name__, pd.__version__)

# %%
text = pd.read_pickle("../data/movies_lines_train.p")

# %%
text.shape
# Out:
# (202394, 9)

# %%
text.head()
# Out:
#   movie_id gender_to gender_from char_id_from char_id_to line_id  \
# 0      m18         m           m         u284       u288  L34746
# 1      m18         m           m         u284       u288  L34747
# 2      m18         m           m         u284       u288  L34748
# 3      m18         m           m         u284       u288  L34749
# 4      m18         m           m         u284       u288  L34750
#
#                                         words movie_year  genre
# 0                                   hello tom       1932  drama
# 1                                you you want       1932  drama
# 2  you suppose anybody want money money money       1932  drama
# 3       listen i tell you i interested deal i       1932  drama
# 4                                 i want know       1932  drama

# %% [markdown]
# ### Common n-grams

# %%
def grams_df(df, numgrams):

    grams_df = pd.DataFrame({'grams': [], 'line_id': []})

    for index, row in df.iterrows():
        #print(index)
        #create list of bigrams for each text
        text = row['words']    
        token = nltk.word_tokenize(text)
        grams_list = list(ngrams(token, numgrams))
        #grams_list = [gram for gram in grams]

        #create dict of ngrams
        line = row['line_id']
        gen = row['gender_from']
        d = {'grams': grams_list, 'line_id': np.repeat(line, len(grams_list)), 'gender_from': np.repeat(gen, len(grams_list))}
        grams_df = pd.concat([grams_df, pd.DataFrame(d)], axis = 0)
        
    return grams_df

# %%
test = text[:5]

# %%
grams_df = grams_df(test,3)
grams_df

# %%
bigrams = grams_df(text[:10000],2)

# %%
bigrams = grams_df(text[:50000],2)

# %%
bigrams['grams'].value_counts()[:10]

# %%
# remove unknown gender
bigrams = bigrams[bigrams['gender_from'] != '?']

# get counts
grouped = bigrams.groupby(['gender_from', 'grams']).count()
g = grouped['line_id'].groupby(level=0, group_keys=False).apply(lambda x: x.sort_values(ascending=False).head(10))
g

# %%
bigrams_genre = pd.merge(bigrams, text[['genre', 'line_id']], on = 'line_id')

# %%
bigrams_genre.head()

# %%
grouped2 = bigrams_genre.groupby(['genre','gender_from', 'grams']).count()
g2 = grouped2['line_id'].groupby(['genre', 'gender_from'], group_keys=False).apply(lambda x: x.sort_values(ascending=False).head(5))
g2.reset_index()

# %% [markdown]
# ### Topic Modeling

# %%
#mallet_path = '/Users/jasmindial/Desktop/mallet-2.0.8/bin/mallet'
mallet_path = "../mallet-2.0.8/bin/mallet"

# %%
# remove terms with low frequency
total = []
for index, row in text.iterrows():
    text = row['words']    
    token = nltk.word_tokenize(text)
    total.extend(token)

# %%
high_freq = nltk.FreqDist(total).most_common(round(.9*text.shape[0]))
high_freq_words = [word for word in total if word in high_freq]
len(high_freq_words)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-e1c4ca756a5d> in <module>()
#       1 high_freq = nltk.FreqDist(total).most_common(round(.9*text.shape[0]))
# ----> 2 high_freq_words = [word for word in total if word in high_freq]
#       3 len(high_freq_words)
#
# <ipython-input-80-e1c4ca756a5d> in <listcomp>(.0)
#       1 high_freq = nltk.FreqDist(total).most_common(round(.9*text.shape[0]))
# ----> 2 high_freq_words = [word for word in total if word in high_freq]
#       3 len(high_freq_words)
#
# KeyboardInterrupt:

# %%
# get two separate texts 
women = text[text['gender_from'] == 'f']
women.name = 'women'
men = text[text['gender_from'] == 'm']
men.name = 'men'

# %%
women.shape
# Out:
# (51762, 9)

# %%
men.shape
# Out:
# (125707, 9)

# %%
stopWords = set(stopwords.words('english'))

# %%
# source: https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/
# trying the genism version

# %%
def add_ngrams(texts):
    
    bigram = gensim.models.Phrases(texts, common_terms=stopWords, min_count=5, threshold=50) 
    trigram = gensim.models.Phrases(bigram[texts], threshold=15)  

    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stopWords] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    
    return texts

# %%
def prep_for_model(series):
    
    # convert to list
    data = series.values.tolist()

    # tokenize 
    def sent_to_words(sentences):
        for sentence in sentences:
            yield(gensim.utils.simple_preprocess(str(sentence)))  

    data_words = list(sent_to_words(data)) 
    data_words = add_ngrams(data_words)
    
    # create dictionary
    id2word = corpora.Dictionary(data_words)

    # Term Document Frequency
    corpus = [id2word.doc2bow(text) for text in data_words]
    
    return data_words, id2word, corpus

# %%
lda_model.inference(corpus)
# Out:
# (array([[ 17.18964386,  21.65542603,  17.41967201,  16.59394264,
#           19.61369705,  20.64762497],
#         [ 17.35377312,  21.83590126,  17.58157158,  16.76119995,
#           19.77800179,  20.80955887],
#         [ 17.80370903,  25.46050644,  20.09745598,  17.21982193,
#           21.25831985,  22.28019333],
#         ...,
#         [ 19.3858223 ,  21.84412003,  20.63464737,  17.74871445,
#           20.72269249,  22.78401184],
#         [ 18.90226364,  21.31130791,  18.07350159,  19.24811363,
#           21.26449966,  21.32032013],
#         [ 17.18407631,  20.68430138,  17.41448402,  16.58744431,
#           19.6081028 ,  20.64159966]], dtype=float32), None)

# %%
# just testing 
data_words, id2word, corpus = prep_for_model(women.words)
# make sure grams are working
len(set([word for sent in data_words for word in sent if "_" in word]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# 259

# %%
# doesn't like this
#lda_model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=8, id2word=id2word)

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):

    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        print (num_topics)
        lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,id2word=id2word, num_topics=num_topics, 
                                                    random_state=100, update_every=1, chunksize=100, passes=10,
                                                    alpha='auto', per_word_topics=True)
        #lda_model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(lda_model)
        coherencemodel = CoherenceModel(model=lda_model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# run models and get coherence values
# model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus,
                                                        #texts=data_words, start=3, limit=13, step=3)

# %%
# run topic modeling for both gender scripts 
# this takes a while :)

common_genres = ["action", "drama", "comedy", "crime"]
#dictionary of models
d = {genre:{} for genre in common_genres}

topics = []
coherence = []

for gen in [women, men]:
    print (gen.name)
    for x in common_genres:
        df = gen[gen.genre == x]
        group = df.words
    
        data_words, id2word, corpus = prep_for_model(group)
        model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus,
                                                            texts=data_words, start=6, limit=8, step=1)
        winner = np.argmax(coherence_values)
        d[x][gen.name] = model_list[winner]
        topics.append(model_list[winner].show_topics())
        coherence.append(max(coherence_values))
# Out:
# women
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7
# men
# 6
# 7
# 6
# 7
# 6
# 7
# 6
# 7

# %%
topics

# %%
#just making features that don't make sense

text_topics = pd.concat([text,pd.DataFrame(columns=["WT1", "WT2", "WT3", "MT1", "MT2", "MT3"])])


for gender in [women.name, men.name]: 
    #choose a model 
    model = d["action"][gender]
    
    #get gamma, probability of topics for each row
    #indices = [0, 51762, 103524, 155286, len(text_topics)]
    indices = [x for x in range(0, len(text_topics), 5000)]
    indices.append(len(text_topics))
    splits = [text_topics.index[indices[i]:indices[i+1]] for i in range(len(indices)-1)]
    subsets = [text_topics.iloc[split] for split in splits]
    for subset in subsets: 
        data_words, id2word, corpus = prep_for_model(subset.words)
        try: 
            gammas = model.inference(corpus)[0]
        except IndexError: 
            print ("index!")

        else: 
            print ("ok!")
            trunc_gammas = [x[:3] for x in gammas]


        if gender == "women":
            text_topics.loc[subset.index, ['WT1', 'WT2', "WT3"]] = trunc_gammas
        if gender == "men":
            text_topics.loc[subset.index, ['MT1', 'MT2', "MT3"]] = trunc_gammas
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!
# ok!

# %%
text_topics
# Out:
#             MT1      MT2      MT3      WT1      WT2      WT3 char_id_from  \
# 0       16.5968  9.97471  19.1337  6.36164  5.24558  7.95344         u284
# 1       16.5951  9.96215  18.1664  6.36196  5.24587  6.95191         u284
# 2       17.0569  10.2537  18.7859  6.50846  8.46322  8.14919         u284
# 3       16.4452  10.8388  19.0021  6.52132  6.41796  8.14794         u284
# 4       16.5934  9.96072  18.1645  6.52725  5.39572  7.14272         u284
# 5       18.1788  11.4773  18.7887  9.27622  8.25359  9.74949         u284
# 6       16.7801  12.1978  19.3462  7.37867  6.26157  9.96075         u284
# 7       16.5905  9.96959  18.1575  6.36178  6.24483  6.95363         u284
# 8       17.5914    9.963  18.1497  6.65751  8.67703  6.24347         u284
# 9       16.5865  9.96602  20.1702  6.51204  8.46925  6.10125         u284
# 10      16.4451  9.83919   18.002  6.36155   5.2455  5.95388         u284
# 11      16.5906  9.96972  18.1577  6.36214   7.2426  5.95445         u284
# 12      16.4452   9.8392   19.002  6.36165  7.24499  5.95398         u284
# 13      16.4452  9.83926  19.0016  7.36156  6.24528  5.95393         u284
# 14      16.7361  10.8302   19.331   7.9346  6.52329  8.56248         u286
# 15      17.6099  9.97199  23.1673  6.49414  5.36525  10.1812         u286
# 16      17.8994  11.2569  19.4666  6.96446  5.74034  6.45044         u286
# 17      18.8799  12.2587  20.4651  13.2984  6.81913  8.64306         u286
# 18       18.445   9.8392   18.002  7.55678  5.39521   6.1153         u286
# 19      18.4447  9.83926  18.0021  7.55088  6.42107   6.1104         u286
# 20      18.5828  10.9611  22.1633  12.6861  9.03122  6.49315         u286
# 21      16.4462  12.8328  19.0037  6.63955  10.7622  7.27105         u286
# 22      19.3708  11.5532  20.1818  9.93591  8.81524   7.3983         u286
# 23      16.5855  9.96512  18.1522  6.57615   5.6385  6.17076         u286
# 24      17.0558  10.3946  24.8791  9.15253  11.6848  7.64736         u286
# 25      16.4453  10.8393  22.0011  6.66096  6.57609  7.30144         u286
# 26       17.603    9.961  18.1649  6.36213  6.24505  6.95204         u286
# 27      16.4451  9.83919   18.002  6.36155   5.2455  5.95388         u286
# 28      17.5931   9.9473  18.1768   7.4024   6.2845  5.98861         u286
# 29       17.075  10.4066  18.7376  10.8682  7.74025  7.39784         u286
# ...         ...      ...      ...      ...      ...      ...          ...
# 202364  19.7742  12.0019  21.5055  9.16135  7.74594  12.2344        u8251
# 202365  17.2928  10.5602  21.0115  9.34524  7.63873  8.63066        u8251
# 202366  17.4462  9.84039  19.9942  7.92486  5.68746  6.42448        u8251
# 202367  18.4179  11.0123  20.0587  7.92457  6.66356  8.66552        u8251
# 202368  16.9243  10.2259  18.4834  6.68472  6.64858  7.26994        u8240
# 202369  16.4455  10.8393  18.0024  6.86554  5.71119  6.44874        u8240
# 202370  17.6058  9.96913  19.1434  6.71453  6.55466  6.37775        u8240
# 202371  16.4502   9.8437  18.9732  6.55495  5.35825  6.22071        u8240
# 202372  16.4454  11.8393  18.0022  6.52075  5.39132  7.13862        u8240
# 202373  16.5972  9.97778  19.1044  6.73304  5.66722  6.30035        u8240
# 202374  16.6137  9.97528  18.1717  6.53089   5.3983  6.11996        u8240
# 202375   16.882  11.2377  19.4385  7.05512  5.97021  6.61485        u8240
# 202376     17.6  9.96997   18.158  6.36409  6.23643  5.95634        u8240
# 202377  16.4455  9.83953  18.0024  6.52487  5.39848  6.11475        u8240
# 202378  18.1185  10.3835  20.2873  6.93405  9.20741  7.58908        u8240
# 202379  17.5718  10.9862  18.1606  6.86516  5.71883  6.46687        u8240
# 202380  17.5532  10.1762   19.147  6.46161  5.43552  7.15376        u8240
# 202381  16.5922  9.97114  18.1594  6.53222   5.3994  6.11943        u8240
# 202382  18.1398  10.6513  19.8297  6.76613  6.71882  7.44002        u8240
# 202383  16.4452   9.8392  19.0019  6.52525  5.39453  6.11529        u8240
# 202384   17.445  9.83921   18.002  7.31253  5.26098   5.9648        u8240
# 202385  17.2494  10.5373  18.8422  8.11351   6.9497  7.25581        u8240
# 202386  16.6801  10.0486  18.2534  6.51843  6.41727  6.11886        u8240
# 202387  18.3845  10.6748  20.1459  9.23102  8.43461  7.45147        u8240
# 202388  16.4451  9.83919   18.002   6.3616  5.24555  5.95393        u8240
# 202389  17.4451   9.8392   18.002  6.36939  6.20579  5.96165        u8240
# 202390  19.3508  10.5861  18.9161  6.92926  7.93622  10.8381        u8240
# 202391  16.4451  9.83919   18.002   6.3617  6.24477  5.95403        u8240
# 202392  16.7387  10.1039  18.3161  6.71499  5.55361   6.2277        u8240
# 202393  16.7264  10.0927  19.3199  6.84658   5.6978  8.49635        u8240
#
#        char_id_to gender_from gender_to  genre  line_id movie_id movie_year  \
# 0            u288           m         m  drama   L34746      m18       1932
# 1            u288           m         m  drama   L34747      m18       1932
# 2            u288           m         m  drama   L34748      m18       1932
# 3            u288           m         m  drama   L34749      m18       1932
# 4            u288           m         m  drama   L34750      m18       1932
# 5            u288           m         m  drama   L34758      m18       1932
# 6            u288           m         m  drama   L34759      m18       1932
# 7            u288           m         m  drama   L34760      m18       1932
# 8            u288           m         m  drama   L34786      m18       1932
# 9            u288           m         m  drama   L34787      m18       1932
# 10           u288           m         m  drama   L34788      m18       1932
# 11           u288           m         m  drama   L34789      m18       1932
# 12           u288           m         m  drama   L34790      m18       1932
# 13           u288           m         m  drama   L34791      m18       1932
# 14           u288           m         m  drama   L34797      m18       1932
# 15           u288           m         m  drama   L34798      m18       1932
# 16           u288           m         m  drama   L34799      m18       1932
# 17           u288           m         m  drama   L34829      m18       1932
# 18           u288           m         m  drama   L34830      m18       1932
# 19           u288           m         m  drama   L34844      m18       1932
# 20           u288           m         m  drama   L34845      m18       1932
# 21           u288           m         m  drama   L34912      m18       1932
# 22           u288           m         m  drama   L34913      m18       1932
# 23           u288           m         m  drama   L34920      m18       1932
# 24           u288           m         m  drama   L34921      m18       1932
# 25           u288           m         m  drama   L34922      m18       1932
# 26           u288           m         m  drama   L35255      m18       1932
# 27           u288           m         m  drama   L35256      m18       1932
# 28           u288           m         m  drama   L35257      m18       1932
# 29           u288           m         m  drama   L35330      m18       1932
# ...           ...         ...       ...    ...      ...      ...        ...
# 202364      u8254           ?         ?  drama  L586646     m560       2001
# 202365      u8254           ?         ?  drama  L586647     m560       2001
# 202366      u8254           ?         ?  drama  L586648     m560       2001
# 202367      u8254           ?         ?  drama  L586649     m560       2001
# 202368      u8255           m         m  drama  L586393     m560       2001
# 202369      u8255           m         m  drama  L586394     m560       2001
# 202370      u8255           m         m  drama  L586395     m560       2001
# 202371      u8255           m         m  drama  L586396     m560       2001
# 202372      u8255           m         m  drama  L586397     m560       2001
# 202373      u8255           m         m  drama  L586398     m560       2001
# 202374      u8255           m         m  drama  L586399     m560       2001
# 202375      u8255           m         m  drama  L586400     m560       2001
# 202376      u8255           m         m  drama  L586401     m560       2001
# 202377      u8255           m         m  drama  L586402     m560       2001
# 202378      u8255           m         m  drama  L586404     m560       2001
# 202379      u8255           m         m  drama  L586405     m560       2001
# 202380      u8255           m         m  drama  L586657     m560       2001
# 202381      u8255           m         m  drama  L586658     m560       2001
# 202382      u8255           m         m  drama  L586664     m560       2001
# 202383      u8255           m         m  drama  L586665     m560       2001
# 202384      u8256           m         ?  drama  L585963     m560       2001
# 202385      u8256           m         ?  drama  L585964     m560       2001
# 202386      u8256           m         ?  drama  L585965     m560       2001
# 202387      u8256           m         ?  drama  L585966     m560       2001
# 202388      u8256           m         ?  drama  L585967     m560       2001
# 202389      u8256           m         ?  drama  L585968     m560       2001
# 202390      u8256           m         ?  drama  L585969     m560       2001
# 202391      u8256           m         ?  drama  L586519     m560       2001
# 202392      u8256           m         ?  drama  L586520     m560       2001
# 202393      u8256           m         ?  drama  L586521     m560       2001
#
#                                                     words
# 0                                               hello tom
# 1                                            you you want
# 2              you suppose anybody want money money money
# 3                   listen i tell you i interested deal i
# 4                                             i want know
# 5       tom i never trouble get credit you i flat brok...
# 6       i tell you i like crowd you mix personally you...
# 7                                          listen tom i 
# 8       idea turn her it sound like perfectly safe inv...
# 9                    she widow i like take mortgage widow
# 10
# 11                                  she pay i foreclose i
# 12                                             yes sure 
# 13                                              yeah sure
# 14      say you know i find something yesterday hit go...
# 15      i think mr dickson we would like little your v...
# 16      oh you would eh right it important golf go ahe...
# 17      matter my policy many loss bank take last twen...
# 18                                              pure luck
# 19                              character hmmpf your idea
# 20      alexander hamilton idea 5 fine banking mind co...
# 21      creditor i know personally i see them grow com...
# 22      i know dickson well you take many chance time ...
# 23                            i run bank my way get clear
# 24      gentleman you notice mr dickson refuse conside...
# 25            yes you say it clark thing mean anything me
# 26                                       we want talk you
# 27
# 28                                   we discus board room
# 29      we force shut door i work twenty five year nig...
# ...                                                   ...
# 202364  yes they say virulent proponent final solution...
# 202365  paper go report tomorrow your colleague curtis...
# 202366             curtis always complicated he seem even
# 202367  solemn day jewish year former yeshiva student ...
# 202368                        jeez it since kenny wedding
# 202369                                     yeah uh you go
# 202370                             i rabbinic program jts
# 202371                                                jts
# 202372                    you you something strange i bet
# 202373                           i kind underground thing
# 202374                                         you artist
# 202375          kind underground private business private
# 202376                                you remember miriam
# 202377                                       yeah hey you
# 202378  she yale law intern district attorney we get m...
# 202379                                       wow uh great
# 202380                             listen danny you barge
# 202381                                               shut
# 202382  danny listen people expect me daven they want ...
# 202383                                         get my way
# 202384                                              hello
# 202385  daniel balint my name guy danielsen i reporter...
# 202386                                  i new york time i
# 202387  i piece right wing group post oklahoma city i ...
# 202388                                           tell you
# 202389                                            it true
# 202390  it yeah it true you get number maybe sunday pl...
# 202391                                               know
# 202392                                      jewish prayer
# 202393          anybody imagine i would say jewish prayer
#
# [202394 rows x 15 columns]

# %%
pickle.dump(text_topics, open('../data/movies_lines_train_topics.p', 'wb'))

# %%
text_topics.shape
[s[indices[i]:indices[i+1]] for i in xrange(len(indices)-1)]
# Out:
# (202394, 15)

# %%
splits = [0, 51762, 103524, 155286, len(text_topics)]

# %%
testing = [text_topics.index[splits[i]:splits[i+1]] for i in range(len(splits)-1)]

# %%
text_topics.iloc[testing[1]]
# Out:
#         MT1  MT2  MT3  WT1  WT2  WT3 char_id_from char_id_to gender_from  \
# 51762   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51763   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51764   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51765   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51766   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51767   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51768   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51769   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51770   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51771   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51772   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51773   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51774   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51775   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51776   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51777   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51778   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51779   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51780   NaN  NaN  NaN  NaN  NaN  NaN        u8830      u8843           m
# 51781   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8844           m
# 51782   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8844           m
# 51783   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8844           m
# 51784   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8844           m
# 51785   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8844           m
# 51786   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8844           m
# 51787   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8844           m
# 51788   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8844           m
# 51789   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8845           m
# 51790   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8845           m
# 51791   NaN  NaN  NaN  NaN  NaN  NaN        u8836      u8845           m
# ...     ...  ...  ...  ...  ...  ...          ...        ...         ...
# 103494  NaN  NaN  NaN  NaN  NaN  NaN        u7005      u7013           ?
# 103495  NaN  NaN  NaN  NaN  NaN  NaN        u7009      u7013           ?
# 103496  NaN  NaN  NaN  NaN  NaN  NaN        u7009      u7013           ?
# 103497  NaN  NaN  NaN  NaN  NaN  NaN        u7009      u7013           ?
# 103498  NaN  NaN  NaN  NaN  NaN  NaN        u7009      u7013           ?
# 103499  NaN  NaN  NaN  NaN  NaN  NaN        u7009      u7013           ?
# 103500  NaN  NaN  NaN  NaN  NaN  NaN        u7009      u7013           ?
# 103501  NaN  NaN  NaN  NaN  NaN  NaN        u7009      u7013           ?
# 103502  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103503  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103504  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103505  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103506  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103507  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103508  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103509  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103510  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103511  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103512  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2448           f
# 103513  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103514  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103515  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103516  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103517  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103518  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103519  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103520  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103521  NaN  NaN  NaN  NaN  NaN  NaN        u2444      u2448           ?
# 103522  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2452           f
# 103523  NaN  NaN  NaN  NaN  NaN  NaN        u2443      u2452           f
#
#        gender_to   genre  line_id movie_id movie_year  \
# 51762          f   crime  L645156     m599       1987
# 51763          f   crime  L645157     m599       1987
# 51764          f   crime  L645158     m599       1987
# 51765          f   crime  L645159     m599       1987
# 51766          f   crime  L645160     m599       1987
# 51767          f   crime  L645161     m599       1987
# 51768          f   crime  L645162     m599       1987
# 51769          f   crime  L645163     m599       1987
# 51770          f   crime  L645164     m599       1987
# 51771          f   crime  L645253     m599       1987
# 51772          f   crime  L645254     m599       1987
# 51773          f   crime  L645356     m599       1987
# 51774          f   crime  L645357     m599       1987
# 51775          f   crime  L645358     m599       1987
# 51776          f   crime  L645359     m599       1987
# 51777          f   crime  L645360     m599       1987
# 51778          f   crime  L645362     m599       1987
# 51779          f   crime  L645363     m599       1987
# 51780          f   crime  L645364     m599       1987
# 51781          ?   crime  L645125     m599       1987
# 51782          ?   crime  L645126     m599       1987
# 51783          ?   crime  L645127     m599       1987
# 51784          ?   crime  L645128     m599       1987
# 51785          ?   crime  L645129     m599       1987
# 51786          ?   crime  L645130     m599       1987
# 51787          ?   crime  L645137     m599       1987
# 51788          ?   crime  L645138     m599       1987
# 51789          ?   crime  L645300     m599       1987
# 51790          ?   crime  L645301     m599       1987
# 51791          ?   crime  L645305     m599       1987
# ...          ...     ...      ...      ...        ...
# 103494         ?  action  L438133     m468       2001
# 103495         ?  action  L437710     m468       2001
# 103496         ?  action  L437711     m468       2001
# 103497         ?  action  L437712     m468       2001
# 103498         ?  action  L437714     m468       2001
# 103499         ?  action  L437715     m468       2001
# 103500         ?  action  L437716     m468       2001
# 103501         ?  action  L437717     m468       2001
# 103502         m  action  L436413     m157       2000
# 103503         m  action  L436414     m157       2000
# 103504         m  action  L436415     m157       2000
# 103505         m  action  L436416     m157       2000
# 103506         m  action  L436422     m157       2000
# 103507         m  action  L436423     m157       2000
# 103508         m  action  L436424     m157       2000
# 103509         m  action  L436465     m157       2000
# 103510         m  action  L436466     m157       2000
# 103511         m  action  L436467     m157       2000
# 103512         m  action  L436468     m157       2000
# 103513         m  action  L436364     m157       2000
# 103514         m  action  L436365     m157       2000
# 103515         m  action  L436366     m157       2000
# 103516         m  action  L436367     m157       2000
# 103517         m  action  L436368     m157       2000
# 103518         m  action  L436369     m157       2000
# 103519         m  action  L436435     m157       2000
# 103520         m  action  L436436     m157       2000
# 103521         m  action  L436437     m157       2000
# 103522         m  action  L436586     m157       2000
# 103523         m  action  L436587     m157       2000
#
#                                                     words
# 51762                                                okay
# 51763   you i hear you guy handle fairchild food merge...
# 51764         come buddy you want get me disbar would you
# 51765            listen it one college buddy talk another
# 51766                                          yeah right
# 51767          relax roger everybody it you know you know
# 51768                                            i it moi
# 51769   money you ever dream roger thing one get hurt ...
# 51770                                     much i walk you
# 51771                                  you put dime roger
# 51772                                    right bud let it
# 51773                                             problem
# 51774   get strange call sec they ask see my record bu...
# 51775   relax roget you 82m account number i invisible...
# 51776   alright i wanna slow bud call awhile lunch we ...
# 51777                sure roger whatever you want it cool
# 51778   gekko ask u bluestar deal we review timetable ...
# 51779                                    he never tell me
# 51780                 you president company you know come
# 51781   rare pistol world larry 45 luger six ever manu...
# 51782   congratulation rare still your interest anacot...
# 51783   interest yours larry money i think it good inv...
# 51784   time i long term liquidation gordon i go turn ...
# 51785   you must wear mask you laugh hard behind it la...
# 51786   i could break you mate two piece my knee you k...
# 51787               consider you bring my mother it 71 50
# 51788                done you hear my lawyer 8 good night
# 51789              due respect mr gekko prevent you thing
# 51790   cause i way around way we make money make airl...
# 51791                             you prepare put writing
# ...                                                   ...
# 103494  we fail lose our carrier we destroy our abilit...
# 103495  you join u admiral u think your education amer...
# 103496  knowledge opponent careful calculation danger ...
# 103497  time come strike sit let american cut our oil ...
# 103498                         you something say yamamoto
# 103499  council know i oppose fight american matter gr...
# 103500                             you see u capable blow
# 103501  american themselves make it possible we annihi...
# 103502  i know you gabriel marion last time i saw you ...
# 103503                    i uh me it samuel i mean nathan
# 103504                it you it turn my teeth black month
# 103505                                            uh uh i
# 103506  i know you go look like i never would put ink ...
# 103507                                you call compliment
# 103508                                           it start
# 103509                         next time we bring blanket
# 103510                                         would nice
# 103511                    maybe we lucky winter rain snow
# 103512                                         would nice
# 103513                         he make light redcoat kill
# 103514                                      he make light
# 103515                              you know him well you
# 103516                                       he my father
# 103517                             i know him well enough
# 103518  fault him grow frontier it hard time hard plac...
# 103519                             you get salt last week
# 103520           oh right bake powder we need bake powder
# 103521  we get plenty bake powder you go pembroke get ...
# 103522                        i sorry we give you warning
# 103523                             it alright i happy you
#
# [51762 rows x 15 columns]

# %%
text_topics.iloc[10:20]
# Out:
#     MT1  MT2  MT3  WT1  WT2  WT3 char_id_from char_id_to gender_from  \
# 10  NaN  NaN  NaN  NaN  NaN  NaN         u284       u288           m
# 11  NaN  NaN  NaN  NaN  NaN  NaN         u284       u288           m
# 12  NaN  NaN  NaN  NaN  NaN  NaN         u284       u288           m
# 13  NaN  NaN  NaN  NaN  NaN  NaN         u284       u288           m
# 14  NaN  NaN  NaN  NaN  NaN  NaN         u286       u288           m
# 15  NaN  NaN  NaN  NaN  NaN  NaN         u286       u288           m
# 16  NaN  NaN  NaN  NaN  NaN  NaN         u286       u288           m
# 17  NaN  NaN  NaN  NaN  NaN  NaN         u286       u288           m
# 18  NaN  NaN  NaN  NaN  NaN  NaN         u286       u288           m
# 19  NaN  NaN  NaN  NaN  NaN  NaN         u286       u288           m
#
#    gender_to  genre line_id movie_id movie_year  \
# 10         m  drama  L34788      m18       1932
# 11         m  drama  L34789      m18       1932
# 12         m  drama  L34790      m18       1932
# 13         m  drama  L34791      m18       1932
# 14         m  drama  L34797      m18       1932
# 15         m  drama  L34798      m18       1932
# 16         m  drama  L34799      m18       1932
# 17         m  drama  L34829      m18       1932
# 18         m  drama  L34830      m18       1932
# 19         m  drama  L34844      m18       1932
#
#                                                 words
# 10
# 11                              she pay i foreclose i
# 12                                         yes sure 
# 13                                          yeah sure
# 14  say you know i find something yesterday hit go...
# 15  i think mr dickson we would like little your v...
# 16  oh you would eh right it important golf go ahe...
# 17  matter my policy many loss bank take last twen...
# 18                                          pure luck
# 19                          character hmmpf your idea

# %%
# run topic modeling for both overall gender scripts 
# add the results to the dictionary

topics2 = []
coherence2 = []

for gen in [women.words, men.words]:
    
    data_words, id2word, corpus = prep_for_model(gen)
    model_list, coherence_values = compute_coherence_values(mallet_path, dictionary=id2word, corpus=corpus,
                                                        texts=data_words, start=8, limit=11, step=2)
    winner = np.argmax(coherence_values)
    d['overall'][gen.name] = model_list[winner]
    topics2.append(model_list[winner].show_topics())
    coherence2.append(max(coherence_values))

# %%
# create features for classification

# create empty features to be filled
text_topics = pd.concat([text,pd.DataFrame(columns=["WT1", "WT2", "WT3", "MT1", "MT2", "MT3"])])


for gender in [women.name, men.name]: 
    for genre in common_genres:
        #subset the data
        subset = text[text.genre == genre]
        #select appropriate model 
        model = d[genre][gender]
        #get gamma, probability of topics for each row 
        data_words, id2word, corpus = prep_for_model(subset.words)
        try: 
            gammas = model.inference(corpus)[0]
        except IndexError: 
            print ("index!")
            
        else: 
            print ("ok!")
        
        
        
    """
        
        print (gammas)
        #add array to dataframe
        #concat values to the main dataframe??
        if gender == "women":
            text_topics.loc[text_topics.genre == genre, ['WT1', 'WT2', "WT3"]] = gammas
        if gender == "men":
            text_topics.loc[text_topics.genre == genre, ['MT1', 'MT2', "MT3"]] = gammas
    
   
    # for lines that are not common genres, use gender-based topic models 
    uncommon_genres = text_topics[text_topics.genre not in common_genres]
    #model = d[overall][gender] eventually change to this
    model = d['action'][gender]
    gammas = model.inference(uncommon_genres)
    if gender == "women":
        text_topics.loc[text_topics.genre not in common_genres, ['WT1', 'WT2', "WT3"]] = gammas
    if gender == "men":
        text_topics.loc[text_topics.genre not in common_genres, ['MT1', 'MT2', "MT3"]] = gammas
    """
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# index!
# index!
# index!
# index!
# index!
# index!
# index!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-bb64964cbc72> in <module>()
#      12         model = d[genre][gender]
#      13         #get gamma, probability of topics for each row
# ---> 14         data_words, id2word, corpus = prep_for_model(subset.words)
#      15         try:
#      16             gammas = model.inference(corpus)[0]
#
# <ipython-input-111-d42cba2c6390> in prep_for_model(series)
#      10
#      11     data_words = list(sent_to_words(data))
# ---> 12     data_words = add_ngrams(data_words)
#      13
#      14     # create dictionary
#
# <ipython-input-110-a654e185236a> in add_ngrams(texts)
#       4     trigram = gensim.models.Phrases(bigram[texts], threshold=15)
#       5
# ----> 6     bigram_mod = gensim.models.phrases.Phraser(bigram)
#       7     trigram_mod = gensim.models.phrases.Phraser(trigram)
#       8
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py in __init__(self, phrases_model)
#     579         logger.info('source_vocab length %i', len(phrases_model.vocab))
#     580         count = 0
# --> 581         for bigram, score in phrases_model.export_phrases(corpus, self.delimiter, as_tuples=True):
#     582             if bigram in self.phrasegrams:
#     583                 logger.info('Phraser repeat %s', bigram)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py in export_phrases(self, sentences, out_delimiter, as_tuples)
#     467             # keeps only not None scores
#     468             filtered = ((words, score) for words, score in bigrams if score is not None)
# --> 469             for words, score in filtered:
#     470                 if as_tuples:
#     471                     yield (tuple(words), score)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py in <genexpr>(.0)
#     466             bigrams = analyze_sentence(sentence)
#     467             # keeps only not None scores
# --> 468             filtered = ((words, score) for words, score in bigrams if score is not None)
#     469             for words, score in filtered:
#     470                 if as_tuples:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py in analyze_sentence(self, sentence, threshold, common_terms, scorer)
#     165                     wordb=word,
#     166                     components=chain,
# --> 167                     scorer=scorer,
#     168                 )
#     169                 if score > threshold:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py in score_item(self, worda, wordb, components, scorer)
#     130
#     131     def score_item(self, worda, wordb, components, scorer):
# --> 132         vocab = self.vocab
#     133         if worda in vocab and wordb in vocab:
#     134             bigram = self.delimiter.join(components)
#
# KeyboardInterrupt:

# %%
type(corpus)
# Out:
# list

# %%
test = subset[subset.gender_from == 'f']
test.shape
# Out:
# (7808, 9)

# %%
#need to split the data into chunks, too long right now!! 

data_words, id2word, corpus = prep_for_model(subset.words[:100])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
test_gammas = model.inference(corpus)[0]

# %%
trunc_gammas = [x[:3] for x in test_gammas]

# %%
len(test_gammas)
# Out:
# 7808

# %%
topics[0]

# %%
topics[1]

# %%
coherence

# %%
# coherence_values w 5,10,15,20 and w/o removing stop words (10 does best)

# %%
# coherence_values w 4,8,12,16,20 and w/o removing stop words (8 does best)

# %%
# trying the sklearn version

texts = [men.words, women.words]

# %%
ngram_range = [(1,1), (2,3)] # bag of words, bigrams and trigrams
max_features = [1000]
no_topics = [8, 10, 15]
no_top_words = [5, 10]

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ,".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        
# inspiration source: https://medium.com/mlreview/topic-modeling-with-scikit-learn-e80d33668730

# %%
# only lda                       

def topic_model(texts):

    for a in ngram_range:
        print (a)
        for x in max_features:
            print (x)
            for y in no_topics: 
                print (y)
                for text in texts: 

                    #transform
                    count_vect = CountVectorizer(ngram_range = a, max_features = x, stop_words = 'english') # using bigrams and trigrams
                    word_counts = count_vect.fit_transform(text, )
                    tfidf_transformer = TfidfTransformer()
                    words_tfidf = tfidf_transformer.fit_transform(word_counts)

                    lda = LatentDirichletAllocation(n_topics=y, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(word_counts) 
                        
                    for z in no_top_words: 
                        print (z)
                        display_topics(lda, count_vect.get_feature_names(), z)

# %%
topic_model(texts)

# %%
# transform
count_vect = CountVectorizer(ngram_range = (2,3), max_features = 1000, stop_words = 'english') # using bigrams and trigrams
w_words_counts = count_vect.fit_transform(women.words, )
tfidf_transformer = TfidfTransformer()
w_words_tfidf = tfidf_transformer.fit_transform(w_words_counts)

# %%
# transform
#count_vect2 = CountVectorizer(ngram_range = (2,3)) # using bigrams and trigrams
count_vect2 = CountVectorizer(ngram_range = (2,3), max_features = 1000, stop_words = 'english') # using bigrams and trigrams
m_words_counts = count_vect2.fit_transform(men.words, )
tfidf_transformer = TfidfTransformer()
m_words_tfidf = tfidf_transformer.fit_transform(m_words_counts)

# %%
nmf = NMF(n_components=20, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(w_words_tfidf)
nmf2 = NMF(n_components=20, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(m_words_tfidf)

# %%
# Run LDA for women
lda = LatentDirichletAllocation(n_topics=10, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(w_words_counts)

# %%
# LDA for men
lda2 = LatentDirichletAllocation(n_topics=10, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(m_words_counts)

# %%
no_top_words = 10
display_topics(lda, count_vect.get_feature_names(), no_top_words)

# %%
display_topics(lda2, count_vect.get_feature_names(), no_top_words)

# %%
no_top_words = 10
display_topics(nmf2, count_vect2.get_feature_names(), no_top_words)

# %%
# count_vect.vocabulary_

# %%
# words_tfidf[1,:].toarray()
